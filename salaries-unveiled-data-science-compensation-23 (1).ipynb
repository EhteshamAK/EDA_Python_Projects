# %% [markdown]
# ![Data Scientist Salaries](https://www.boston.com/wp-content/uploads/2017/03/1118800c-2a31-11e3-9705-17b312947581.jpg)

# %% [markdown]
# # <p style="background-color:#40128B; font-family:newtimeroman;color:#F9F5F6; font-size:150%; text-align:center; border-radius: 15px 50px;">  EDA </p>

# %% [markdown]
# <p style="background-color:#40118B; font-family:newtimeroman;color:#F9F5F6; font-size:150%; text-align:center; border-radius: 15px 50px;">Purpose of EDA</p>
#
# - The purpose of EDA for the "Data Science Salaries 2023" dataset is to gain a comprehensive understanding of the dataset's characteristics, patterns, and relationships.
# - EDA helps uncover distributions and trends related to work experience levels, job titles, salary ranges, remote work ratios, and company sizes.
# - It allows us to identify key insights and observations about the data, such as common job titles, salary distributions, remote work availability, and company size distributions.
# - EDA helps validate assumptions and preconceived notions about the data, ensuring its credibility and reliability.
# - It provides actionable information to support decision-making for stakeholders, job seekers, employers, and policymakers.
# - EDA helps identify data quality issues, missing values, outliers, and inconsistencies, aiding in data cleaning and preparation.
# - Overall, EDA sets the foundation for further analysis, uncovers valuable information, and informs decision-making in the data science industry.

# %% [markdown]
# ## EDA Step by Step
#
#   * [Import Libraries and Dataset](#section_one)
#   * [Understand the data](#section_two)
#   * [Guiding Questions & Visualization](#section_four)
#   * [Conclusions ](#section_five)

# %% [markdown]
# <p style="background-color:#F9F5F6; font-family:>Purpose of EDA</p>

# %% [markdown]
# <a id="section_one"></a>
# ###  Import Libraries and Dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# import the dataset 
df = pd.read_csv("/kaggle/input/data-science-salaries-2023/ds_salaries.csv")
df.head(20)
# Out:
#     work_year experience_level employment_type                 job_title  \
# 0        2023               SE              FT  Principal Data Scientist
# 1        2023               MI              CT               ML Engineer
# 2        2023               MI              CT               ML Engineer
# 3        2023               SE              FT            Data Scientist
# 4        2023               SE              FT            Data Scientist
# 5        2023               SE              FT         Applied Scientist
# 6        2023               SE              FT         Applied Scientist
# 7        2023               SE              FT            Data Scientist
# 8        2023               SE              FT            Data Scientist
# 9        2023               SE              FT            Data Scientist
# 10       2023               SE              FT            Data Scientist
# 11       2023               SE              FT              Data Analyst
# ...

# %%
df.tail()
# Out:
#       work_year experience_level employment_type                 job_title  \
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
#        salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 3750   412000             USD         412000                 US           100
# 3751   151000             USD         151000                 US           100
# 3752   105000             USD         105000                 US           100
# 3753   100000             USD         100000                 US           100
# 3754  7000000             INR          94665                 IN            50
#
#      company_location company_size
# ...

# %% [markdown]
# <a id="section_two"></a>
# ###  Understand the data

# %%
# shape of the dataset 
df.shape
# Out:
# (3755, 11)

# %%
# datatypes
df.dtypes
# Out:
# work_year              int64
# experience_level      object
# employment_type       object
# job_title             object
# salary                 int64
# salary_currency       object
# salary_in_usd          int64
# employee_residence    object
# remote_ratio           int64
# company_location      object
# company_size          object
# dtype: object

# %%
# columns in the data
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
# check the missing values in the data
df.isnull().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %% [markdown]
# There are no missing values in the dataset

# %%
# info about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3755 entries, 0 to 3754
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           3755 non-null   int64
#  1   experience_level    3755 non-null   object
#  2   employment_type     3755 non-null   object
#  3   job_title           3755 non-null   object
#  4   salary              3755 non-null   int64
#  5   salary_currency     3755 non-null   object
#  6   salary_in_usd       3755 non-null   int64
#  7   employee_residence  3755 non-null   object
#  8   remote_ratio        3755 non-null   int64
#  9   company_location    3755 non-null   object
#  10  company_size        3755 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 322.8+ KB

# %%
#Statistical information about the numeric data
df.describe()
# Out:
#          work_year        salary  salary_in_usd  remote_ratio
# count  3755.000000  3.755000e+03    3755.000000   3755.000000
# mean   2022.373635  1.906956e+05  137570.389880     46.271638
# std       0.691448  6.716765e+05   63055.625278     48.589050
# min    2020.000000  6.000000e+03    5132.000000      0.000000
# 25%    2022.000000  1.000000e+05   95000.000000      0.000000
# 50%    2022.000000  1.380000e+05  135000.000000      0.000000
# 75%    2023.000000  1.800000e+05  175000.000000    100.000000
# max    2023.000000  3.040000e+07  450000.000000    100.000000

# %%
# Statistical information about the categorical data
df.describe(include=object)
# Out:
#        experience_level employment_type      job_title salary_currency  \
# count              3755            3755           3755            3755
# unique                4               4             93              20
# top                  SE              FT  Data Engineer             USD
# freq               2516            3718           1040            3224
#
#        employee_residence company_location company_size
# count                3755             3755         3755
# unique                 78               72            3
# top                    US               US            M
# freq                 3004             3040         3153

# %%
#Unique values in the dataset 
df.nunique()
# Out:
# work_year                4
# experience_level         4
# employment_type          4
# job_title               93
# salary                 815
# salary_currency         20
# salary_in_usd         1035
# employee_residence      78
# remote_ratio             3
# company_location        72
# company_size             3
# dtype: int64

# %%
# duplicate values
df.duplicated().sum()
# Out:
# 1171

# %% [markdown]
# We are not removing the duplicate values, some job titles are repeated in different regions

# %% [markdown]
# <a id="section_four"></a>
# # Guiding Questions & Visualization

# %% [markdown]
# #### 1. Explore the distribution of work experience levels:

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='experience_level')
plt.xlabel('Experience Level')
plt.ylabel('Count')
plt.title('Distribution of Work Experience Levels')
plt.show()

# %% [markdown]
# #### 2. Investigate the types of employment and their frequencies:

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='employment_type')
plt.xlabel('Employment Type')
plt.ylabel('Count')
plt.title('Frequency of Employment Types')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### 3. Identify the most common job titles:

# %%
plt.figure(figsize=(10, 6))
top_job_titles = df['job_title'].value_counts().head(10)
sns.barplot(x=top_job_titles, y=top_job_titles.index)
plt.xlabel('Count')
plt.ylabel('Job Title')
plt.title('Top 10 Most Common Job Titles')
plt.show()

# %% [markdown]
# #### 4. Analyze the salary distribution across job titles:

# %%
plt.figure(figsize=(12, 18))
sns.boxplot(data=df, y='job_title', x='salary_in_usd')
plt.xlabel('Salary (in USD)')
plt.ylabel('Job Title')
plt.title('Salary Distribution Across Job Titles')
plt.show()

# %% [markdown]
#  #### 5. Explore the employee residence locations:

# %%
plt.figure(figsize=(10, 6))
top_residences = df['employee_residence'].value_counts().head(10)
sns.barplot(x=top_residences, y=top_residences.index)
plt.xlabel('Count')
plt.ylabel('Residence')
plt.title('Top 10 Employee Residence Locations')
plt.show()

# %% [markdown]
# #### 5. Remote work ratio across job titles

# %%
plt.figure(figsize=(12, 18))
sns.boxplot(data=df, y='job_title', x='remote_ratio')
plt.xlabel('Remote Work Ratio')
plt.ylabel('Job Title')
plt.title('Remote Work Ratio Across Job Titles')
plt.show()

# %% [markdown]
# #### 6. Distribution of company sizes

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='company_size')
plt.xlabel('Company Size')
plt.ylabel('Count')
plt.title('Distribution of Company Sizes')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# <a id="section_five"></a>
# ###  Conclusion

# %% [markdown]
# In conclusion, the "Data Science Salaries 2023" dataset sheds light on the key aspects of data science employment, providing valuable information for stakeholders and the wider audience. Through EDA and visualizations, we have explored the distribution of work experience levels, identified the most common job titles, analyzed salary variations across different roles, examined remote work opportunities, and examined the distribution of company sizes. These insights help professionals make informed decisions regarding their career paths, assist employers in understanding industry standards for compensation and remote work, and provide a comprehensive overview of the data science job market. By leveraging the findings from this dataset, stakeholders and the audience can navigate the dynamic landscape of data science salaries and employment trends, enabling them to make informed choices and drive successful outcomes in the field of data science.
